# %% [markdown]
# <a href="https://colab.research.google.com/github/zih-yan/abc1/blob/main/EX03_03_%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%8C%87%E6%A8%99(AQI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=58d6040c-dca7-407f-a244-d0bfdfa8144a&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant status  so2    co    o3  o3_8hr  pm10  ...  \
# 0       基隆    基隆市   39       NaN     良好  1.7  0.24  42.0    42.0  18.0  ...
# 1       汐止    新北市   68     細懸浮微粒     普通  1.0  0.16  53.0    54.0  34.0  ...
# 2       萬里    新北市   52     細懸浮微粒     普通  0.4  0.15  39.0    43.0  24.0  ...
# 3       新店    新北市   63     細懸浮微粒     普通  1.6  0.18  59.0    54.0  37.0  ...
# 4       土城    新北市   76     細懸浮微粒     普通  0.9  0.19  51.0    45.0  44.0  ...
#
#    wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg pm10_avg  \
# 0         0.8         327  2025/04/22 16:00:00     0.2       9.3       17
# 1         2.7         255  2025/04/22 16:00:00     0.2      18.7       33
# 2         3.3          30  2025/04/22 16:00:00     0.2      12.7       24
# 3         2.7         298  2025/04/22 16:00:00     0.2      16.9       32
# 4         2.8         241  2025/04/22 16:00:00     0.2      21.6       39
#
#   so2_avg   longitude   latitude  siteid
# 0       1  121.760056  25.129167       1
# 1       0  121.640810  25.066240       2
# 2       0  121.689881  25.179667       3
# 3       0  121.537778  24.977222       4
# 4       0  121.451861  24.982528       5
#
# [5 rows x 24 columns]

# %%
df = df[['sitename', 'county','pollutant','status','aqi']]
df
# Out:
#        sitename county pollutant status  aqi
# 0            基隆    基隆市       NaN     良好   39
# 1            汐止    新北市     細懸浮微粒     普通   68
# 2            萬里    新北市     細懸浮微粒     普通   52
# 3            新店    新北市     細懸浮微粒     普通   63
# 4            土城    新北市     細懸浮微粒     普通   76
# ..          ...    ...       ...    ...  ...
# 81       屏東（琉球）    屏東縣      懸浮微粒     普通   62
# 82  台中市（和平區消防隊）    臺中市       NaN     良好   31
# 83       新北（樹林）    新北市      懸浮微粒     普通   54
# 84       臺南（南化）    臺南市       NaN     良好   33
# 85       屏東(枋山)    屏東縣       NaN     良好   42
#
# [86 rows x 5 columns]

# %%
condition = df['aqi'] > 100
df[condition]
# Out:
# Empty DataFrame
# Columns: [sitename, county, pollutant, status, aqi]
# Index: []

# %%
condition = df['county'] == '高雄市'
df[condition]
# Out:
#    sitename county pollutant status  aqi
# 46       美濃    高雄市       NaN     良好   46
# 47       橋頭    高雄市     細懸浮微粒     普通   54
# 48       仁武    高雄市       NaN     良好   46
# 49       鳳山    高雄市     細懸浮微粒     普通   57
# 50       大寮    高雄市     細懸浮微粒     普通   59
# 51       林園    高雄市     細懸浮微粒     普通   55
# 52       楠梓    高雄市      懸浮微粒     普通   53
# 53       左營    高雄市     細懸浮微粒     普通   52
# 54       前金    高雄市       NaN     良好   37
# 55       前鎮    高雄市       NaN     良好   41
# 56       小港    高雄市       NaN     良好   44
# 69       復興    高雄市       NaN     良好   42
# 80   高雄（湖內）    高雄市       NaN     良好   41

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 連江縣    78.000000
# 新竹市    67.000000
# 新北市    65.692308
# 臺北市    64.857143
# 新竹縣    61.000000
# 桃園市    59.500000
# 金門縣    59.000000
# 苗栗縣    57.666667
# 澎湖縣    56.000000
# 彰化縣    54.400000
# 臺中市    51.333333
# 臺南市    50.800000
# 南投縣    50.666667
# 屏東縣    48.400000
# 高雄市    48.230769
# 雲林縣    46.750000
# 嘉義縣    46.000000
# 宜蘭縣    45.666667
# 嘉義市    45.000000
# 基隆市    39.000000
# 花蓮縣    36.000000
# 臺東縣    34.000000
# Name: aqi, dtype: float64
